# %%
import pandas as pd
import os

# %%
df = pd.read_csv('species_complete.csv')
df.head()
# Out:
#                index  AphiaID     ScientificName   Kingdom    Phylum  \
# 0  Madrepora oculata   135209  Madrepora oculata  Animalia  Cnidaria
# 1  Madrepora oculata   135209  Madrepora oculata  Animalia  Cnidaria
# 2  Madrepora oculata   135209  Madrepora oculata  Animalia  Cnidaria
# 3  Madrepora oculata   135209  Madrepora oculata  Animalia  Cnidaria
# 4  Madrepora oculata   135209  Madrepora oculata  Animalia  Cnidaria
#
#       Class      Subclass         Order      Family      Genus  \
# 0  Anthozoa  Hexacorallia  Scleractinia  Oculinidae  Madrepora
# 1  Anthozoa  Hexacorallia  Scleractinia  Oculinidae  Madrepora
# 2  Anthozoa  Hexacorallia  Scleractinia  Oculinidae  Madrepora
# 3  Anthozoa  Hexacorallia  Scleractinia  Oculinidae  Madrepora
# 4  Anthozoa  Hexacorallia  Scleractinia  Oculinidae  Madrepora
#
#     VernacularNameCategory  latitude  longitude  DepthInMeters  \
# 0  stony coral (branching)  18.30817 -158.45392          959.0
# ...

# %%
sample = df.head(1000)
sample
# Out:
#                        index  AphiaID           ScientificName   Kingdom  \
# 0          Madrepora oculata   135209        Madrepora oculata  Animalia
# 1          Madrepora oculata   135209        Madrepora oculata  Animalia
# 2          Madrepora oculata   135209        Madrepora oculata  Animalia
# 3          Madrepora oculata   135209        Madrepora oculata  Animalia
# 4          Madrepora oculata   135209        Madrepora oculata  Animalia
# 5          Madrepora oculata   135209        Madrepora oculata  Animalia
# 6          Madrepora oculata   135209        Madrepora oculata  Animalia
# 7          Madrepora oculata   135209        Madrepora oculata  Animalia
# 8          Madrepora oculata   135209        Madrepora oculata  Animalia
# 9          Madrepora oculata   135209        Madrepora oculata  Animalia
# 10         Madrepora oculata   135209        Madrepora oculata  Animalia
# 11         Madrepora oculata   135209        Madrepora oculata  Animalia
# ...

# %%
import gmaps
gmaps.configure(api_key='AIzaSyBejMXp63dhTDOZGR2c53lDM1CMW5jT7R4')
marker_locations = sample[['latitude','longitude']]
species_tag = sample["ScientificName"].tolist()
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Species: {sp}" for sp in species_tag])
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
